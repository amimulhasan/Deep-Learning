# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/Deep-Learning/blob/main/Untitled100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download ashrafulhossenakash/alzheimer-disease-dataset
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'

# %%
import zipfile

zip_path = '/content/alzheimer-disease-dataset.zip'
extract_to = 'Alzheimer disease'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Unzipping completed!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1582255007.py in <cell line: 0>()
#       4 extract_to = 'Alzheimer disease'
#       5
# ----> 6 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       7     zip_ref.extractall(extract_to)
#       8
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1334             while True:
#    1335                 try:
# -> 1336                     self.fp = io.open(file, filemode)
#    1337                 except OSError:
#    1338                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/alzheimer-disease-dataset.zip'

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers, callbacks
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split

# %%
IMG_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 60
DATA_DIR = "/content/Alzheimer disease/Alzheimer_Dataset_V2/train"  # <-- Update this path
CLASS_NAMES = os.listdir(DATA_DIR)       # ['MildDemented','ModerateDemented','NonDemented','VeryMildDemented']
NUM_CLASSES = len(CLASS_NAMES)

# %%
X = []
y = []

for idx, cls in enumerate(CLASS_NAMES):
    cls_dir = os.path.join(DATA_DIR, cls)
    for fname in os.listdir(cls_dir):
        fpath = os.path.join(cls_dir, fname)
        img = image.load_img(fpath, target_size=(IMG_SIZE, IMG_SIZE))
        img = image.img_to_array(img)
        img = img / 255.0  # normalize
        X.append(img)
        y.append(idx)

X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.int32)

print("Dataset shapes -> X:", X.shape, "y:", y.shape)

# %%
def augment_images(imgs):
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.8,1.2]
    )
    return datagen.flow(imgs, np.zeros(len(imgs)), batch_size=len(imgs), shuffle=False)[0]
